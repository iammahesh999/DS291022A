# %%
#####
## Modules (import )

# %%
######### Packages ########

# A Python Module can be a simple python File (. py extension file), i.e., a combination of 
# numerous Functions and Global variables.
#  A Python Package/libraries is a collection of different Python modules with an __init__.py File. __init__.py

# %%
import pandas as pd ### handle the files and many more things
import numpy as np

# %%
### File Handling ### ( txt, .xls, .xlsx, .csv, .pdf., json etc)
import pandas as pd

a = 10
df = pd.read_excel("/content/data (6).xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df   # Dataframe ( table (combination of row and columns))
# Out:
#                                             Job Title                   Skills
# 0                             .net software developer  microsoft visual studio
# 1                             .net software developer       Project Management
# 2                             .net software developer          Software Design
# 3                             .net software developer               VirtualBox
# 4                             .net software developer             Visual Basic
# ...                                               ...                      ...
# 5779                        wqsoftwares web developer         Microsoft Office
# 5780                        wqsoftwares web developer               Web Design
# 5781             xitranet software systems proprietor          system software
# 5782                                              NaN                      NaN
# 5783  Applied filters:\nJob Title contains 'software'                      NaN
#
# [5784 rows x 2 columns]

# %%
a = [10,20,'Uttam', "Grade"]
a[0]
# Out:
# 10

# %%
type(df['Job Title'][0])
# Out:
# str

# %%
df.iloc[4][0]
# Out:
# '.net software developer'

# %%
df['Job Title'][0]#.replace('.net', 'python')
# Out:
# 'python software developer'

# %%
type(a)
# Out:
# list

# %%
type(df['Job Title'])
# Out:
# pandas.core.series.Series

# %%
for i in a:

  print(i,'---')
# Out:
# 10 ---
# 20 ---
# Uttam ---
# Grade ---

# %%
len(df['Job Title'])
# Out:
# 5784

# %%
def rep(x):
  c = x.replace(' ', '-')
  return c

# %%
rep(df['Job Title'][0])
# Out:
# '.net-software-developer'

# %%
for i in df['Job Title']:
  i = i.replace('java', ' ')
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
#   software developer
#   software developer
#   software developer
#   software developer
#   software developer
#   software developer
#   software developer
#   software developer
#   software developer
#   software developer
#   software engineer
#   software engineer
#   software engineer
#   software engineer
#   software engineer
#   software engineer
#   software engineer
#   software engineer
#   software engineer
#   software engineer
#   software engineer
#   software engineer
# Jr. IOS Software Developer
# Jr. IOS Software Developer
# Jr. Software Developer
# Jr. Software Developer Industrial Training
# Jr. Software Developer Industrial Training
# Jr. Software Developer Industrial Training
# Jr. Software Developer Industrial Training
# Jr. Software Developer Industrial Training
# Jr. Software Developer Industrial Training
# Jr. Software Developer Industrial Training
# Jr.Software Developer
# Jr.Software Developer
# ...
